# %%
# !hydromt --models
# Out:
# hydroMT model plugins: sfincs (v0.2.1)

# %%
fn_ini = "sfincs_forcing_wg_climx.ini"
with open(fn_ini, "r") as f:
    txt = f.read()
print(txt)
# Out:
# [setup_config]
# tref = 19810103 000000
# tstart = 19810103 000000
# tstop = 20101231 000000
# alpha = 0.5
# zsini = 0.5
#
# [setup_h_forcing]
# geodataset_fn = data/gtsm_locations_bangkok.csv  # waterlevel gauge locations
# timeseries_fn = data/gtsm_timeseries.csv  # waterlevel time series --> Try to run it with 0 or leave empty
# buffer = 1e4                    # buffer around model region to select gauges
#
# [setup_q_forcing_from_grid]
# discharge_fn = wflow_output_climx     # Discharge forcing from wflow ['discharge']
# uparea_fn = wflow_static_climx         # Static output from wflow for upstream areas
# wdw = 2
# rel_error = 0.1 ## rel error en abs error

# %%
# !hydromt update --help

# %%
os.environ['HDF5_USE_FILE_LOCKING']='FALSE'

# %%
# !hydromt update sfincs ./sfincs_bangkok -o ./sfincs_update_bangkok_wg_1981-2010b_climx_1 -i sfincs_forcing_wg_climx.ini -d P:/11206881-climate-risk-in-cities/msc_theses/Jasper/hydromt_wflow-main/Case_studies/output/wflow_forcing.yml --dd -vv
# Out:
# 2022-06-16 10:04:06,973 - update - log - DEBUG - Writing log messages to new file \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_update_bangkok_wg_1981-2010b_climx_1\hydromt.log.
# 2022-06-16 10:04:06,974 - update - log - INFO - HydroMT version: 0.4.6.dev
# 2022-06-16 10:04:06,975 - update - main - INFO - Updating sfincs model at \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_bangkok (r).
# 2022-06-16 10:04:06,976 - update - main - INFO - Output dir: \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_update_bangkok_wg_1981-2010b_climx_1
# 2022-06-16 10:04:06,976 - update - main - INFO - Additional data sources: ('\\\\storage009.directory.intra\\11206881-climate-risk-in-cities\\msc_theses\\Jasper\\hydromt_wflow-main\\Case_studies\\output\\wflow_forcing.yml',)
# 2022-06-16 10:04:06,977 - update - main - INFO - User settings:
# 2022-06-16 10:04:07,087 - update - model_plugins - DEBUG - Loaded model plugin 'sfincs = hydromt_sfincs.sfincs.SfincsModel' (0.2.1)
# 2022-06-16 10:04:07,095 - update - data_adapter - INFO - Adding deltares_data v0.0.6 sources from https://github.com/DirkEilander/hydromt-artifacts/releases/download/v0.0.6/deltares_data.yml
# 2022-06-16 10:04:08,406 - update - data_adapter - WARNING - Overwriting data source era5_hourly.
# 2022-06-16 10:04:08,410 - update - data_adapter - WARNING - Overwriting data source fabdem.
# 2022-06-16 10:04:08,415 - update - data_adapter - WARNING - Overwriting data source gcn250.
# 2022-06-16 10:04:08,416 - update - data_adapter - WARNING - Overwriting data source merit_hydro.
# 2022-06-16 10:04:08,418 - update - data_adapter - WARNING - Overwriting data source osm_coastlines.
# 2022-06-16 10:04:08,419 - update - data_adapter - WARNING - Overwriting data source rivers_lin2019_v1.
# 2022-06-16 10:04:08,419 - update - data_adapter - WARNING - Overwriting data source vito.
# 2022-06-16 10:04:08,451 - update - log - DEBUG - Appending log messages to file \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_bangkok\hydromt.log.
# 2022-06-16 10:04:08,459 - update - model_api - INFO - Initializing sfincs model from hydromt_sfincs (v0.2.1).
# 2022-06-16 10:04:08,477 - update - model_api - DEBUG - Model config read from \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_bangkok\sfincs.inp
# 2022-06-16 10:04:09,367 - update - sfincs - DEBUG - waterlevel forcing: setting bnd data for 6 points.
# 2022-06-16 10:04:09,369 - update - sfincs - DEBUG - waterlevel forcing: setting bzs data.
# 2022-06-16 10:04:09,479 - update - sfincs - DEBUG - discharge forcing: setting src data for 1 points.
# 2022-06-16 10:04:09,480 - update - sfincs - DEBUG - discharge forcing: setting dis data.
# 2022-06-16 10:04:09,498 - update - sfincs - DEBUG - precip forcing: setting precip data.
# 2022-06-16 10:04:09,501 - update - sfincs - INFO - Model read
# 2022-06-16 10:04:09,524 - update - log - DEBUG - Appending log messages to file \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_update_bangkok_wg_1981-2010b_climx_1\hydromt.log.
# 2022-06-16 10:04:09,526 - update - model_api - ERROR - missing required argument cfdict for setup_config
# 2022-06-16 10:04:09,527 - update - model_api - DEBUG - Setting model config options.
# 2022-06-16 10:04:09,528 - update - model_api - INFO - setup_h_forcing.geodataset_fn: \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\data\gtsm_locations_bangkok.csv
# 2022-06-16 10:04:09,529 - update - model_api - INFO - setup_h_forcing.timeseries_fn: \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\data\gtsm_timeseries.csv
# 2022-06-16 10:04:09,530 - update - model_api - INFO - setup_h_forcing.offset_fn: None
# 2022-06-16 10:04:09,531 - update - model_api - INFO - setup_h_forcing.buffer: 10000.0
# 2022-06-16 10:04:09,568 - update - data_adapter - WARNING - Overwriting data source gtsm_locations_bangkok.
# 2022-06-16 10:04:09,572 - update - data_adapter - INFO - DataCatalog: Getting gtsm_locations_bangkok GeoDataset vector data from \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\data\gtsm_locations_bangkok.csv
# 2022-06-16 10:04:10,024 - update - data_adapter - INFO - GeoDataset: Read vector data and clip to geom (epsg:32647) [633050.000, 1481450.000, 693550.000, 1513900.000].
# 2022-06-16 10:04:10,110 - update - data_adapter - DEBUG - GeoDataset: Slicing time dim (datetime.datetime(1981, 1, 3, 0, 0), datetime.datetime(2010, 12, 31, 0, 0))
# 2022-06-16 10:04:10,121 - update - sfincs - DEBUG - waterlevel forcing: setting bnd data for 6 points.
# 2022-06-16 10:04:10,124 - update - sfincs - DEBUG - waterlevel forcing: setting bzs data.
# 2022-06-16 10:04:10,125 - update - model_api - WARNING - Replacing forcing: bzs
# 2022-06-16 10:04:10,126 - update - model_api - INFO - setup_q_forcing_from_grid.discharge_fn: wflow_output_climx
# 2022-06-16 10:04:10,127 - update - model_api - INFO - setup_q_forcing_from_grid.locs_fn: None
# 2022-06-16 10:04:10,128 - update - model_api - INFO - setup_q_forcing_from_grid.uparea_fn: wflow_static_climx
# 2022-06-16 10:04:10,129 - update - model_api - INFO - setup_q_forcing_from_grid.wdw: 2
# 2022-06-16 10:04:10,130 - update - model_api - INFO - setup_q_forcing_from_grid.rel_error: 0.1
# 2022-06-16 10:04:10,130 - update - model_api - INFO - setup_q_forcing_from_grid.abs_error: 50
# 2022-06-16 10:04:10,138 - update - data_adapter - INFO - DataCatalog: Getting wflow_output_climx RasterDataset netcdf data from P:\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_wflow-main\Case_studies\wflow_update_bangkok_wg_1981-2010b_climx_1\run_default\output.nc
# 2022-06-16 10:04:11,963 - update - data_adapter - DEBUG - RasterDataset: Slicing time dim (datetime.datetime(1981, 1, 3, 0, 0), datetime.datetime(2010, 12, 31, 0, 0))
# 2022-06-16 10:04:11,981 - update - data_adapter - DEBUG - RasterDataset: Clip with geom - [100.322, 13.487, 100.699, 13.899]
# 2022-06-16 10:04:12,017 - update - data_adapter - INFO - DataCatalog: Getting wflow_static_climx RasterDataset netcdf data from P:\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_wflow-main\Case_studies\wflow_update_bangkok_wg_1981-2010b_climx_1\staticmaps.nc
# 2022-06-16 10:04:13,156 - update - data_adapter - DEBUG - RasterDataset: Clip with geom - [100.322, 13.487, 100.699, 13.899]
# 2022-06-16 10:04:13,270 - update - discharge - DEBUG - Snapping discharge points to best matching uparea cell within wdw (size=2).
# 2022-06-16 10:04:13,691 - update - sfincs - DEBUG - discharge forcing: setting src data for 1 points.
# 2022-06-16 10:04:13,695 - update - sfincs - DEBUG - discharge forcing: setting dis data.
# 2022-06-16 10:04:13,696 - update - model_api - WARNING - Replacing forcing: dis
# 2022-06-16 10:04:13,697 - update - sfincs - INFO - Writing model data to \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_update_bangkok_wg_1981-2010b_climx_1
# 2022-06-16 10:04:13,847 - update - sfincs - DEBUG - Write binary map indices based on mask.
# 2022-06-16 10:04:13,884 - update - sfincs - DEBUG - Write binary map files: ['dep', 'msk', 'scs', 'manning'].
# 2022-06-16 10:04:13,977 - update - sfincs - INFO - Write raster file(s) for staticmaps to 'gis' subfolder
# 2022-06-16 10:04:14,543 - update - sfincs - INFO - Write staticgeom files
# 2022-06-16 10:04:14,565 - update - sfincs - INFO - Write vector file(s) for staticgeoms to 'gis' subfolder
# 2022-06-16 10:04:14,864 - update - sfincs - INFO - Write forcing files
# 2022-06-16 10:11:32,298 - update - sfincs - INFO - Write vector file(s) for forcing.bzs to 'gis' subfolder
# 2022-06-16 10:11:32,455 - update - sfincs - INFO - Write vector file(s) for forcing.dis to 'gis' subfolder
# 2022-06-16 10:11:32,515 - update - model_api - INFO - Writing model config to \\storage009.directory.intra\11206881-climate-risk-in-cities\msc_theses\Jasper\hydromt_sfincs-main\Case_studies\sfincs_update_bangkok_wg_1981-2010b_climx_1\sfincs.inp

# %%
# %matplotlib inline
from hydromt_sfincs import SfincsModel
import matplotlib.pyplot as plt

# %%
# define the model's configuration file
root = r"./sfincs_update_bangkok_wg_historic_1"

# read the model with hydromt sfincs methods
mod = SfincsModel(root=root, mode="r")
mod.read()
_ = mod.plot_basemap(figsize=(16, 12))

# %%
mod.plot_forcing()
# Out:
# (<Figure size 432x648 with 3 Axes>,
#  array([<AxesSubplot:title={'center':'SFINCS waterlevel forcing (bzs)'}, ylabel='waterlevel\n[m+ref]'>,
#         <AxesSubplot:title={'center':'SFINCS discharge forcing (dis)'}, ylabel='discharge\n[m3.s-1]'>,
#         <AxesSubplot:title={'center':'SFINCS precipitation forcing (precip)'}, ylabel='precipitation\n[mm.hr-1]'>],
#        dtype=object))
