# %%
import numpy as np
import xarray as xr
import glob
import os
import hydromt
from dask.diagnostics import ProgressBar

# %%
# setup logging
from hydromt.log import setuplog
logger = setuplog("read raster data", log_level=10)
# Out:
# 2022-05-16 10:48:43,851 - read raster data - log - INFO - HydroMT version: 0.4.5

# %%
# Open data using the deltares data catalog
data_catalog = hydromt.DataCatalog(deltares_data=True, logger=logger)
data_catalog
# Out:
# 2022-05-16 10:48:51,305 - read raster data - data_adapter - INFO - Adding deltares_data v0.0.6 sources from https://github.com/DirkEilander/hydromt-artifacts/releases/download/v0.0.6/deltares_data.yml
#                                                                               path  \
# chelsa                           p:\wflow_global\hydromt\meteo\chelsa_clim_v1.2...
# chelsa_v1.2                      p:\wflow_global\hydromt\meteo\chelsa_clim_v1.2...
# chirps                           p:\wflow_global\hydromt\meteo\chirps_africa_da...
# chirps_africa_daily_v2.0         p:\wflow_global\hydromt\meteo\chirps_africa_da...
# chirps_global                    p:\wflow_global\hydromt\meteo\chirps_global_da...
# ...                                                                            ...
# worldclim_v2.0                   p:\wflow_global\hydromt\meteo\worldclim_v2.0\w...
# worldpop_2020_constrained        p:\wflow_global\hydromt\socio_economic\worldpo...
# worldpop_2020_UNadj_constrained  p:\wflow_global\hydromt\socio_economic\worldpo...
# wsf_bld_2015                     p:\wflow_global\hydromt\infrastructure\wsf\WSF...
# wsf_bld_2015_v1                  p:\wflow_global\hydromt\infrastructure\wsf\WSF...
#
#                                      data_type  driver        category  \
# chelsa                           RasterDataset  raster           meteo
# chelsa_v1.2                      RasterDataset  raster           meteo
# chirps                           RasterDataset  netcdf           meteo
# chirps_africa_daily_v2.0         RasterDataset  netcdf           meteo
# chirps_global                    RasterDataset  netcdf           meteo
# ...                                        ...     ...             ...
# worldclim_v2.0                   RasterDataset  netcdf           meteo
# worldpop_2020_constrained        RasterDataset  raster  socio-economic
# worldpop_2020_UNadj_constrained  RasterDataset  raster  socio-economic
# wsf_bld_2015                     RasterDataset  raster  socio-economic
# wsf_bld_2015_v1                  RasterDataset  raster  socio-economic
#
#                                                     paper_doi  \
# chelsa                                 10.1038/sdata.2017.122
# chelsa_v1.2                            10.1038/sdata.2017.122
# chirps                                  10.1038/sdata.2015.66
# chirps_africa_daily_v2.0                10.1038/sdata.2015.66
# chirps_global                                   10.3133/ds832
# ...                                                       ...
# worldclim_v2.0                               10.1002/joc.5086
# worldpop_2020_constrained        10.1371/journal.pone.0107042
# worldpop_2020_UNadj_constrained  10.1371/journal.pone.0107042
# wsf_bld_2015                       10.1038/s41597-020-00580-5
# wsf_bld_2015_v1                    10.1038/s41597-020-00580-5
#
#                                                paper_ref source_license  \
# chelsa                              Karger et al. (2017)      CC BY 4.0
# chelsa_v1.2                         Karger et al. (2017)      CC BY 4.0
# chirps                                 Funk et al (2015)             CC
# chirps_africa_daily_v2.0               Funk et al (2015)             CC
# chirps_global                          Funk et al (2014)             CC
# ...                                                  ...            ...
# worldclim_v2.0                   Fick and Hijmans (2017)            NaN
# worldpop_2020_constrained          Stevens et al. (2015)      CC BY 4.0
# worldpop_2020_UNadj_constrained    Stevens et al. (2015)      CC BY 4.0
# wsf_bld_2015                     Marconcini at al (2020)        CC0 1.0
# wsf_bld_2015_v1                  Marconcini at al (2020)        CC0 1.0
#
#                                                                         source_url  \
# chelsa                                        http://chelsa-climate.org/downloads/
# chelsa_v1.2                                   http://chelsa-climate.org/downloads/
# chirps                                        https://www.chc.ucsb.edu/data/chirps
# chirps_africa_daily_v2.0                      https://www.chc.ucsb.edu/data/chirps
# chirps_global                                 https://www.chc.ucsb.edu/data/chirps
# ...                                                                            ...
# worldclim_v2.0                     https://www.worldclim.org/data/worldclim21.html
# worldpop_2020_constrained        https://www.worldpop.org/doi/10.5258/SOTON/WP0...
# worldpop_2020_UNadj_constrained  https://www.worldpop.org/doi/10.5258/SOTON/WP0...
# wsf_bld_2015                     https://un-spider.org/links-and-resources/data...
# wsf_bld_2015_v1                  https://un-spider.org/links-and-resources/data...
#
#                                 source_version source_author unit history  \
# chelsa                                     1.2           NaN  NaN     NaN
# chelsa_v1.2                                1.2           NaN  NaN     NaN
# chirps                                    v2.0           NaN  NaN     NaN
# chirps_africa_daily_v2.0                  v2.0           NaN  NaN     NaN
# chirps_global                             v2.0           NaN  NaN     NaN
# ...                                        ...           ...  ...     ...
# worldclim_v2.0                               2           NaN  NaN     NaN
# worldpop_2020_constrained                  NaN           NaN  NaN     NaN
# worldpop_2020_UNadj_constrained            NaN           NaN  NaN     NaN
# wsf_bld_2015                               NaN           NaN  NaN     NaN
# wsf_bld_2015_v1                            NaN           NaN  NaN     NaN
#
#                                 notes source_info author timestamp
# chelsa                            NaN         NaN    NaN       NaN
# chelsa_v1.2                       NaN         NaN    NaN       NaN
# chirps                            NaN         NaN    NaN       NaN
# chirps_africa_daily_v2.0          NaN         NaN    NaN       NaN
# chirps_global                     NaN         NaN    NaN       NaN
# ...                               ...         ...    ...       ...
# worldclim_v2.0                    NaN         NaN    NaN       NaN
# worldpop_2020_constrained         NaN         NaN    NaN       NaN
# worldpop_2020_UNadj_constrained   NaN         NaN    NaN       NaN
# wsf_bld_2015                      NaN         NaN    NaN       NaN
# wsf_bld_2015_v1                   NaN         NaN    NaN       NaN
#
# [124 rows x 16 columns]

# %%
# check out era5_daily
data_catalog["era5"]
# Out:
# {'category': 'meteo',
#  'data_type': 'RasterDataset',
#  'driver': 'netcdf',
#  'history': 'Extracted from Copernicus Climate Data Store; resampled by '
#             'Deltares to daily frequency',
#  'paper_doi': '10.1002/qj.3803',
#  'paper_ref': 'Hersbach et al. (2019)',
#  'path': 'p:\\wflow_global\\hydromt\\meteo\\era5_daily\\nc_merged\\era5_*_daily.nc',
#  'source_license': 'https://cds.climate.copernicus.eu/cdsapp/#!/terms/licence-to-use-copernicus-products',
#  'source_url': 'https://doi.org/10.24381/cds.bd0915c6',
#  'source_version': 'ERA5 daily data on pressure levels'}

# %%
# select start and end time and retrieve dataset
ts = "1981-01-01T00:00:00"
te = "2010-12-31T00:00:00" 
bbox = [97.76,13.1,101.96,20.5] # ymin xmin ymax xmax 
ds = data_catalog.get_rasterdataset("era5_daily", bbox=bbox, buffer=1, time_tuple=(ts, te))  # bbox=[0., 0., 2., 2.]
ds
# Out:
# 2022-05-16 10:49:56,878 - read raster data - data_adapter - INFO - DataCatalog: Getting era5_daily RasterDataset netcdf data from p:\wflow_global\hydromt\meteo\era5_daily\nc_merged\era5_*_daily.nc
# 2022-05-16 10:50:01,802 - read raster data - data_adapter - DEBUG - RasterDataset: Slicing time dim ('1981-01-01T00:00:00', '2010-12-31T00:00:00')
# 2022-05-16 10:50:02,181 - read raster data - data_adapter - DEBUG - RasterDataset: Clip with bbox - [97.760, 13.100, 101.960, 20.500]
# 2022-05-16 10:50:02,195 - read raster data - data_adapter - DEBUG - RasterDataset: Convert units for 6 variables.
# <xarray.Dataset>
# Dimensions:      (time: 10957, longitude: 18, latitude: 32)
# Coordinates:
#   * time         (time) datetime64[ns] 1981-01-01 1981-01-02 ... 2010-12-31
#   * longitude    (longitude) float32 97.75 98.0 98.25 98.5 ... 101.5 101.8 102.0
#   * latitude     (latitude) float32 20.75 20.5 20.25 20.0 ... 13.5 13.25 13.0
#     spatial_ref  int32 1
# Data variables:
#     press_msl    (time, latitude, longitude) float32 dask.array<chunksize=(1, 32, 18), meta=np.ndarray>
#     kin          (time, latitude, longitude) float32 dask.array<chunksize=(1, 32, 18), meta=np.ndarray>
#     temp_min     (time, latitude, longitude) float32 dask.array<chunksize=(1, 32, 18), meta=np.ndarray>
#     temp_max     (time, latitude, longitude) float32 dask.array<chunksize=(1, 32, 18), meta=np.ndarray>
#     temp         (time, latitude, longitude) float32 dask.array<chunksize=(1, 32, 18), meta=np.ndarray>
#     kout         (time, latitude, longitude) float32 dask.array<chunksize=(1, 32, 18), meta=np.ndarray>
#     precip       (time, latitude, longitude) float32 dask.array<chunksize=(1, 32, 18), meta=np.ndarray>
# Attributes:
#     category:        meteo
#     history:         Extracted from Copernicus Climate Data Store; resampled ...
#     paper_doi:       10.1002/qj.3803
#     paper_ref:       Hersbach et al. (2019)
#     source_license:  https://cds.climate.copernicus.eu/cdsapp/#!/terms/licenc...
#     source_url:      https://doi.org/10.24381/cds.bd0915c6
#     source_version:  ERA5 daily data on pressure levels

# %%
dvars = ds.raster.vars
encoding={k: {"zlib": True} for k in dvars}

print("Saving to netcdf")
delayed_obj = ds.to_netcdf("era5_bangkok_1981-2011.nc", encoding=encoding, mode="w", compute=False)
with ProgressBar():
    delayed_obj.compute()
# Out:
# Saving to netcdf
# [########################################] | 100% Completed | 16min 57.6s
